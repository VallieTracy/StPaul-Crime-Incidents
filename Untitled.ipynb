# %%
# Dependencies
import pandas as pd
# %matplotlib inline
import matplotlib.pyplot as plt

# %%
# Read csv into a dataframe
crime_df = pd.read_csv("Resources/crime_report.csv")
crime_df.head()
# Out:
#    CASE NUMBER        DATE                     TIME  CODE  \
# 0     18218701  09/22/2018                 23:32:12  9954
# 1     17042545  02/27/2017                     6:56  1400
# 2     19063393  03/29/2019  2019-03-29T00:14:00.000  2619
# 3     16260773  12/21/2016                    19:29  1410
# 4     18109307  05/23/2018                  6:41:13  9954
#
#                                        INCIDENT TYPE                INCIDENT  \
# 0                             Proactive Police Visit  Proactive Police Visit
# 1                        Criminal Damage to Property               Vandalism
# 2  Weapons, Discharging a Firearm in the City Limits               Discharge
# 3  Criminal Damage to Property (Misdemeanor, Unde...               Vandalism
# 4                             Proactive Police Visit  Proactive Police Visit
#
#    POLICE GRID NUMBER  NEIGHBORHOOD NUMBER                NEIGHBORHOOD NAME  \
# 0               105.0                   13                  13 - Union Park
# 1                71.0                    6                    6 - North End
# 2                98.0                    1  1 - Conway/Battlecreek/Highwood
# 3                70.0                    6                    6 - North End
# 4               207.0                    9                 9 - West Seventh
#
#                BLOCK CALL DISPOSITION CODE CALL DISPOSITION  Count
# 0  137X STANTHONY AV                     A          Advised      1
# 1    13X WINNIPEG AV                     A          Advised      1
# 2   166X MARGARET ST                    RR   Report Written      1
# 3     84X GALTIER ST                    RR   Report Written      1
# 4   108X MONTREAL AV                     A          Advised      1

# %%
# Pull out all rows with nan's just to see
crime_nan = crime_df[crime_df.isna().any(axis=1)]
crime_nan
# Out:
#         CASE NUMBER        DATE                     TIME  CODE  \
# 1020       18054879  03/17/2018                  8:59:26  9954
# 2698       18071249  04/08/2018                  2:49:00  1835
# 6431       18008414  01/13/2018                  5:27:01  9954
# 10170      18224827  09/30/2018                 00:50:09  9954
# 11561      18025800  02/06/2018                  9:39:30  9954
# ...             ...         ...                      ...   ...
# 204468     18021099  01/30/2018                 22:43:00  9954
# 204819     18043425  03/01/2018                 22:49:58  9954
# 207374     17284027  12/10/2017                  9:36:00  9954
# 208404     18039309  02/24/2018                 10:15:23  9954
# 230328     20003804  01/06/2020  2020-01-06T13:38:55.000  9954
#
#                              INCIDENT TYPE                INCIDENT  \
# 1020                Proactive Police Visit  Proactive Police Visit
# 2698    Narcotics, Possession of Marijuana               Narcotics
# 6431                Proactive Police Visit  Proactive Police Visit
# 10170               Proactive Police Visit  Proactive Police Visit
# 11561               Proactive Police Visit  Proactive Police Visit
# ...                                    ...                     ...
# 204468              Proactive Police Visit  Proactive Police Visit
# 204819              Proactive Police Visit  Proactive Police Visit
# 207374              Proactive Police Visit  Proactive Police Visit
# 208404              Proactive Police Visit  Proactive Police Visit
# 230328              Proactive Police Visit  Proactive Police Visit
#
#         POLICE GRID NUMBER  NEIGHBORHOOD NUMBER   NEIGHBORHOOD NAME  \
# 1020                   NaN                    3       3 - West Side
# 2698                   NaN                   10           10 - Como
# 6431                   NaN                    5    5 - Payne/Phalen
# 10170                  NaN                    5    5 - Payne/Phalen
# 11561                  NaN                    3       3 - West Side
# ...                    ...                  ...                 ...
# 204468                 NaN                   17  17 - Capitol River
# 204819                 NaN                   12    12 - St. Anthony
# 207374                 NaN                    3       3 - West Side
# 208404                 NaN                    3       3 - West Side
# 230328                51.0                    6       6 - North End
#
#                           BLOCK CALL DISPOSITION CODE CALL DISPOSITION  Count
# 1020       LILYDALE RD  & WATER                     A          Advised      1
# 2698           DALE ST N & IOWA                    RR   Report Written      1
# 6431         60X LAFAYETTE RD S                     A          Advised      1
# 10170          50X LAFAYETTE RD                     A          Advised      1
# 11561          170X LILYDALE ST                     A          Advised      1
# ...                         ...                   ...              ...    ...
# 204468              11X 10 ST E                     A          Advised      1
# 204819          55X VANDALIA ST                     A          Advised      1
# 207374  LILYDALE ST  & LILYDALE                     A          Advised      1
# 208404         170X LILYDALE ST                     A          Advised      1
# 230328                      NaN                     A          Advised      1
#
# [2288 rows x 13 columns]

# %%
# Another way to look for missing values
crime_df.count()
# Out:
# CASE NUMBER              253709
# DATE                     253709
# TIME                     253706
# CODE                     253709
# INCIDENT TYPE            253709
# INCIDENT                 253709
# POLICE GRID NUMBER       253619
# NEIGHBORHOOD NUMBER      253709
# NEIGHBORHOOD NAME        251518
# BLOCK                    253705
# CALL DISPOSITION CODE    253709
# CALL DISPOSITION         253709
# Count                    253709
# dtype: int64

# %%
# Drop null rows
no_null_crime_df = crime_df.dropna(how='any')

# %%
# Verify counts
no_null_crime_df.count()
# Out:
# CASE NUMBER              251421
# DATE                     251421
# TIME                     251421
# CODE                     251421
# INCIDENT TYPE            251421
# INCIDENT                 251421
# POLICE GRID NUMBER       251421
# NEIGHBORHOOD NUMBER      251421
# NEIGHBORHOOD NAME        251421
# BLOCK                    251421
# CALL DISPOSITION CODE    251421
# CALL DISPOSITION         251421
# Count                    251421
# dtype: int64

# %%
# Look at types of Call Disposition
no_null_crime_df["CALL DISPOSITION CODE"].unique()
# Out:
# array(['A', 'RR', 'G', 'R'], dtype=object)

# %%
# Combine 'RR' and 'R' because they both stand for Report Written from what I can tell from the official dataset
no_null_crime_df = no_null_crime_df.replace({'R': 'RR'})

# Check unique codes again
no_null_crime_df["CALL DISPOSITION CODE"].unique()
# Out:
# array(['A', 'RR', 'G'], dtype=object)

# %%
# Look at 'INCIDENT TYPE' and 'INCIDENT' to see if there are similar values
no_null_crime_df["INCIDENT TYPE"].value_counts()
# Out:
# Proactive Police Visit                               109270
# Theft, Except Auto Theft                              17070
# Motor Vehicle Theft, Automobile                        9865
# Narcotics                                              9307
# Criminal Damage to Property                            8770
#                                                       ...
# Murder, Manslaughter By Negligence                        1
# Theft-Mail/Package                                        1
# Graffiti-Gang (Felony, Over $500)                         1
# Arson, Residential, Multiple, Abandoned, Other            1
# Robbery, Service Station, Other Dangerous Weapons         1
# Name: INCIDENT TYPE, Length: 175, dtype: int64

# %%
# INCIDENT
no_null_crime_df["INCIDENT"].value_counts()
# Out:
# Proactive Police Visit        109270
# Theft                          54312
# Vandalism                      16675
# Auto Theft                     14634
# Narcotics                      13950
# Burglary                       12735
# Simple Asasult Dom.             6541
# Community Engagement Event      6037
# Discharge                       5887
# Robbery                         3894
# Agg. Assault                    2591
# Agg. Assault Dom.               2416
# Graffiti                         992
# Rape                             873
# Arson                            572
# Homicide                          24
# Simple Assault Dom.               16
# Other                              2
# Name: INCIDENT, dtype: int64

# %%
# Combine 'Simple Assault Dom.' (one is misspelled)
no_null_crime_df = no_null_crime_df.replace(
                            {"Simple Asasult Dom.": "Simple Assault Dom."})

# Check value counts again
no_null_crime_df["INCIDENT"].value_counts()
# Out:
# Proactive Police Visit        109270
# Theft                          54312
# Vandalism                      16675
# Auto Theft                     14634
# Narcotics                      13950
# Burglary                       12735
# Simple Assault Dom.             6557
# Community Engagement Event      6037
# Discharge                       5887
# Robbery                         3894
# Agg. Assault                    2591
# Agg. Assault Dom.               2416
# Graffiti                         992
# Rape                             873
# Arson                            572
# Homicide                          24
# Other                              2
# Name: INCIDENT, dtype: int64

# %%
# Use this code if I want to keep both date and time under 'TIME' column
# NOTE: Tableau, this formatting works
# Tableau code: Right-click the field, then Default Properties\Date Format. 
# Then click Custom and paste this into the blank: h:mm:ss AMPM

ser = no_null_crime_df['TIME']
time = pd.to_datetime(ser)
time
# Out:
# 0        2020-06-12 23:32:12
# 1        2020-06-12 06:56:00
# 2        2019-03-29 00:14:00
# 3        2020-06-12 19:29:00
# 4        2020-06-12 06:41:13
#                  ...
# 253704   2020-05-19 00:44:03
# 253705   2020-05-17 12:15:00
# 253706   2020-05-20 14:00:00
# 253707   2020-05-18 23:33:00
# 253708   2020-05-19 08:12:00
# Name: TIME, Length: 251421, dtype: datetime64[ns]

# %%
# This code will just give me the timestamp
# NOTE: This code also works in Tableau
ser = no_null_crime_df['TIME']
time = pd.to_datetime(ser).dt.time
time
# Out:
# 0         23:32:12
# 1         06:56:00
# 2         00:14:00
# 3         19:29:00
# 4         06:41:13
#             ...
# 253704    00:44:03
# 253705    12:15:00
# 253706    14:00:00
# 253707    23:33:00
# 253708    08:12:00
# Name: TIME, Length: 251421, dtype: object

# %%
# Insert new column ('NEW TIME') into dataframe to replace 'TIME' column
no_null_crime_df.insert(2, 'NEW TIME', time)
no_null_crime_df
# Out:
#         CASE NUMBER        DATE  NEW TIME                     TIME  CODE  \
# 0          18218701  09/22/2018  23:32:12                 23:32:12  9954
# 1          17042545  02/27/2017  06:56:00                     6:56  1400
# 2          19063393  03/29/2019  00:14:00  2019-03-29T00:14:00.000  2619
# 3          16260773  12/21/2016  19:29:00                    19:29  1410
# 4          18109307  05/23/2018  06:41:13                  6:41:13  9954
# ...             ...         ...       ...                      ...   ...
# 253704     20093597  05/19/2020  00:44:03  2020-05-19T00:44:03.000   600
# 253705     20802568  05/17/2020  12:15:00  2020-05-17T12:15:00.000   641
# 253706     20094807  05/20/2020  14:00:00  2020-05-20T14:00:00.000   622
# 253707     20093563  05/18/2020  23:33:00  2020-05-18T23:33:00.000  2619
# 253708     20093746  05/19/2020  08:12:00  2020-05-19T08:12:00.000  2619
#
#                                             INCIDENT TYPE  \
# 0                                  Proactive Police Visit
# 1                             Criminal Damage to Property
# 2       Weapons, Discharging a Firearm in the City Limits
# 3       Criminal Damage to Property (Misdemeanor, Unde...
# 4                                  Proactive Police Visit
# ...                                                   ...
# 253704                           Theft, Except Auto Theft
# 253705                       Theft, From Auto, Under $500
# 253706              Theft, Purse Snatching, $501 to $1000
# 253707  Weapons, Discharging a Firearm in the City Limits
# 253708  Weapons, Discharging a Firearm in the City Limits
#
#                       INCIDENT  POLICE GRID NUMBER  NEIGHBORHOOD NUMBER  \
# 0       Proactive Police Visit               105.0                   13
# 1                    Vandalism                71.0                    6
# 2                    Discharge                98.0                    1
# 3                    Vandalism                70.0                    6
# 4       Proactive Police Visit               207.0                    9
# ...                        ...                 ...                  ...
# 253704                   Theft               153.0                   17
# 253705                   Theft               153.0                   17
# 253706                   Theft               153.0                   17
# 253707               Discharge               153.0                   17
# 253708               Discharge               153.0                   17
#
#                       NEIGHBORHOOD NAME               BLOCK  \
# 0                       13 - Union Park   137X STANTHONY AV
# 1                         6 - North End     13X WINNIPEG AV
# 2       1 - Conway/Battlecreek/Highwood    166X MARGARET ST
# 3                         6 - North End      84X GALTIER ST
# 4                      9 - West Seventh    108X MONTREAL AV
# ...                                 ...                 ...
# 253704               17 - Capitol River      34X JACKSON ST
# 253705               17 - Capitol River    11X KELLOGG BD E
# 253706               17 - Capitol River  5 ST E & MINNESOTA
# 253707               17 - Capitol River      5 ST E & CEDAR
# 253708               17 - Capitol River          10X 5 ST E
#
#        CALL DISPOSITION CODE CALL DISPOSITION  Count
# 0                          A          Advised      1
# 1                          A          Advised      1
# 2                         RR   Report Written      1
# 3                         RR   Report Written      1
# 4                          A          Advised      1
# ...                      ...              ...    ...
# 253704                     G  Gone on Arrival      1
# 253705                    RR   Report Written      1
# 253706                    RR   Report Written      1
# 253707                    RR   Report Written      1
# 253708                    RR   Report Written      1
#
# [251421 rows x 14 columns]

# %%
# Drop old 'TIME' column
no_null_crime_df = no_null_crime_df.drop(['TIME'], axis = 1)
no_null_crime_df.head()
# Out:
#    CASE NUMBER        DATE  NEW TIME  CODE  \
# 0     18218701  09/22/2018  23:32:12  9954
# 1     17042545  02/27/2017  06:56:00  1400
# 2     19063393  03/29/2019  00:14:00  2619
# 3     16260773  12/21/2016  19:29:00  1410
# 4     18109307  05/23/2018  06:41:13  9954
#
#                                        INCIDENT TYPE                INCIDENT  \
# 0                             Proactive Police Visit  Proactive Police Visit
# 1                        Criminal Damage to Property               Vandalism
# 2  Weapons, Discharging a Firearm in the City Limits               Discharge
# 3  Criminal Damage to Property (Misdemeanor, Unde...               Vandalism
# 4                             Proactive Police Visit  Proactive Police Visit
#
#    POLICE GRID NUMBER  NEIGHBORHOOD NUMBER                NEIGHBORHOOD NAME  \
# 0               105.0                   13                  13 - Union Park
# 1                71.0                    6                    6 - North End
# 2                98.0                    1  1 - Conway/Battlecreek/Highwood
# 3                70.0                    6                    6 - North End
# 4               207.0                    9                 9 - West Seventh
#
#                BLOCK CALL DISPOSITION CODE CALL DISPOSITION  Count
# 0  137X STANTHONY AV                     A          Advised      1
# 1    13X WINNIPEG AV                     A          Advised      1
# 2   166X MARGARET ST                    RR   Report Written      1
# 3     84X GALTIER ST                    RR   Report Written      1
# 4   108X MONTREAL AV                     A          Advised      1

# %%
no_null_crime_df.dtypes
# Out:
# CASE NUMBER                int64
# DATE                      object
# NEW TIME                  object
# CODE                       int64
# INCIDENT TYPE             object
# INCIDENT                  object
# POLICE GRID NUMBER       float64
# NEIGHBORHOOD NUMBER        int64
# NEIGHBORHOOD NAME         object
# BLOCK                     object
# CALL DISPOSITION CODE     object
# CALL DISPOSITION          object
# Count                      int64
# dtype: object

# %%
no_null_crime_df.head()
# Out:
#    CASE NUMBER        DATE  NEW TIME  CODE  \
# 0     18218701  09/22/2018  23:32:12  9954
# 1     17042545  02/27/2017  06:56:00  1400
# 2     19063393  03/29/2019  00:14:00  2619
# 3     16260773  12/21/2016  19:29:00  1410
# 4     18109307  05/23/2018  06:41:13  9954
#
#                                        INCIDENT TYPE                INCIDENT  \
# 0                             Proactive Police Visit  Proactive Police Visit
# 1                        Criminal Damage to Property               Vandalism
# 2  Weapons, Discharging a Firearm in the City Limits               Discharge
# 3  Criminal Damage to Property (Misdemeanor, Unde...               Vandalism
# 4                             Proactive Police Visit  Proactive Police Visit
#
#    POLICE GRID NUMBER  NEIGHBORHOOD NUMBER                NEIGHBORHOOD NAME  \
# 0               105.0                   13                  13 - Union Park
# 1                71.0                    6                    6 - North End
# 2                98.0                    1  1 - Conway/Battlecreek/Highwood
# 3                70.0                    6                    6 - North End
# 4               207.0                    9                 9 - West Seventh
#
#                BLOCK CALL DISPOSITION CODE CALL DISPOSITION  Count
# 0  137X STANTHONY AV                     A          Advised      1
# 1    13X WINNIPEG AV                     A          Advised      1
# 2   166X MARGARET ST                    RR   Report Written      1
# 3     84X GALTIER ST                    RR   Report Written      1
# 4   108X MONTREAL AV                     A          Advised      1

# %%
# Want to graph by year, so pull year out of Date and create new column

no_null_crime_df["YEAR"] = pd.DatetimeIndex(no_null_crime_df["DATE"]).year

# Preview to make sure it worked
no_null_crime_df.head()
# Out:
#    CASE NUMBER        DATE  NEW TIME  CODE  \
# 0     18218701  09/22/2018  23:32:12  9954
# 1     17042545  02/27/2017  06:56:00  1400
# 2     19063393  03/29/2019  00:14:00  2619
# 3     16260773  12/21/2016  19:29:00  1410
# 4     18109307  05/23/2018  06:41:13  9954
#
#                                        INCIDENT TYPE                INCIDENT  \
# 0                             Proactive Police Visit  Proactive Police Visit
# 1                        Criminal Damage to Property               Vandalism
# 2  Weapons, Discharging a Firearm in the City Limits               Discharge
# 3  Criminal Damage to Property (Misdemeanor, Unde...               Vandalism
# 4                             Proactive Police Visit  Proactive Police Visit
#
#    POLICE GRID NUMBER  NEIGHBORHOOD NUMBER                NEIGHBORHOOD NAME  \
# 0               105.0                   13                  13 - Union Park
# 1                71.0                    6                    6 - North End
# 2                98.0                    1  1 - Conway/Battlecreek/Highwood
# 3                70.0                    6                    6 - North End
# 4               207.0                    9                 9 - West Seventh
#
#                BLOCK CALL DISPOSITION CODE CALL DISPOSITION  Count  YEAR
# 0  137X STANTHONY AV                     A          Advised      1  2018
# 1    13X WINNIPEG AV                     A          Advised      1  2017
# 2   166X MARGARET ST                    RR   Report Written      1  2019
# 3     84X GALTIER ST                    RR   Report Written      1  2016
# 4   108X MONTREAL AV                     A          Advised      1  2018

# %%
# Group the dataframe by Year and Incident
grouped_df = no_null_crime_df.groupby(["YEAR", "INCIDENT"])
Incident_Total = grouped_df["INCIDENT"].count()

# Create dataframe
Incident_Total_df = pd.DataFrame(Incident_Total)
# Preview
Incident_Total_df
# Out:
#                           INCIDENT
# YEAR INCIDENT
# 2014 Agg. Assault              198
#      Agg. Assault Dom.         187
#      Arson                      45
#      Auto Theft               1125
#      Burglary                 1156
# ...                            ...
# 2020 Rape                       52
#      Robbery                   222
#      Simple Assault Dom.       486
#      Theft                    3444
#      Vandalism                1106
#
# [108 rows x 1 columns]

# %%
# Reset the index and rename the column
Incident_Total_df = Incident_Total_df.rename(columns={"INCIDENT": "Count"}).reset_index()
# Preview
Incident_Total_df
# Out:
#      YEAR             INCIDENT  Count
# 0    2014         Agg. Assault    198
# 1    2014    Agg. Assault Dom.    187
# 2    2014                Arson     45
# 3    2014           Auto Theft   1125
# 4    2014             Burglary   1156
# ..    ...                  ...    ...
# 103  2020                 Rape     52
# 104  2020              Robbery    222
# 105  2020  Simple Assault Dom.    486
# 106  2020                Theft   3444
# 107  2020            Vandalism   1106
#
# [108 rows x 3 columns]

# %%
# Reset the index and rename the column
Incident_Total_df = Incident_Total_df.set_index("YEAR")
# Preview
Incident_Total_df
# Out:
#                  INCIDENT  Count
# YEAR
# 2014         Agg. Assault    198
# 2014    Agg. Assault Dom.    187
# 2014                Arson     45
# 2014           Auto Theft   1125
# 2014             Burglary   1156
# ...                   ...    ...
# 2020                 Rape     52
# 2020              Robbery    222
# 2020  Simple Assault Dom.    486
# 2020                Theft   3444
# 2020            Vandalism   1106
#
# [108 rows x 2 columns]

# %%
# Pivot the dataframe for graphing purposes
pivot_df = Incident_Total_df.pivot(index = "YEAR", 
                                   columns = "INCIDENT",
                                   values = "Count")
pivot_df
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2896             try:
# -> 2897                 return self._engine.get_loc(key)
#    2898             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'YEAR'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-22-754dcadb216f> in <module>
#       2 pivot_df = Incident_Total_df.pivot(index = "YEAR",
#       3                                    columns = "INCIDENT",
# ----> 4                                    values = "Count")
#       5 pivot_df
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in pivot(self, index, columns, values)
#    5917         from pandas.core.reshape.pivot import pivot
#    5918
# -> 5919         return pivot(self, index=index, columns=columns, values=values)
#    5920
#    5921     _shared_docs[
#
# ~\Anaconda3\lib\site-packages\pandas\core\reshape\pivot.py in pivot(data, index, columns, values)
#     418             index = data.index
#     419         else:
# --> 420             index = data[index]
#     421         index = MultiIndex.from_arrays([index, data[columns]])
#     422
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2978             if self.columns.nlevels > 1:
#    2979                 return self._getitem_multilevel(key)
# -> 2980             indexer = self.columns.get_loc(key)
#    2981             if is_integer(indexer):
#    2982                 indexer = [indexer]
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2897                 return self._engine.get_loc(key)
#    2898             except KeyError:
# -> 2899                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    2900         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#    2901         if indexer.ndim > 1 or indexer.size > 1:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'YEAR'

# %%
incidents_df = pivot_df[["Agg. Assault", "Agg. Assault Dom.", "Arson","Auto Theft", "Burglary",
                         "Discharge", "Graffiti", "Homicide", "Narcotics", "Rape", "Robbery",
                         "Simple Assault Dom.", "Theft", "Vandalism"]]
incidents_df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-23-f5578f4d6db2> in <module>
# ----> 1 incidents_df = pivot_df[["Agg. Assault", "Agg. Assault Dom.", "Arson","Auto Theft", "Burglary",
#       2                          "Discharge", "Graffiti", "Homicide", "Narcotics", "Rape", "Robbery",
#       3                          "Simple Assault Dom.", "Theft", "Vandalism"]]
#       4 incidents_df
#
# NameError: name 'pivot_df' is not defined

# %%
incidents_df.plot(kind="line", figsize=(20,6))
# Set a title for the chart
plt.title("Total Incidents, 2014-2020")

plt.show()
plt.tight_layout()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-24-5943eb6e9ada> in <module>
# ----> 1 incidents_df.plot(kind="line", figsize=(20,6))
#       2 # Set a title for the chart
#       3 plt.title("Total Incidents, 2014-2020")
#       4
#       5 plt.show()
#
# NameError: name 'incidents_df' is not defined
